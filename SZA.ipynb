# %%
import earthaccess
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
# import h5py

# def print_hdf5_structure(file_path):
#     with h5py.File(file_path, 'r') as f:
#         def print_attrs(name, obj):
#             if isinstance(obj, h5py.Group):
#                 print(f"Group: {name}")
#             elif isinstance(obj, h5py.Dataset):
#                 print(f"  Dataset: {name}")
#         f.visititems(print_attrs)

# # print_hdf5_structure('PACE_HARP2.20250703T210657.L1C.V3.5km.nc')

# %%
auth = earthaccess.login(persist=True)

# %%
# results = earthaccess.search_datasets(instrument="harp2")
# for item in results:
#     summary = item.summary()
#     print(summary["short-name"])

# %%
results = earthaccess.search_data(
    short_name="PACE_HARP2_L1B_SCI", 
    temporal=("2025-07-06T19:20:50", "2025-07-06T19:25:49"),
)
print(len(results))
# Out:
# 2

# %%
# files = earthaccess.download(results, "/umbc/rs/pi_zzbatmos/common/Data/PACE/PACE_HARP2_L1B_SCI")

# %%
path = "/umbc/rs/pi_zzbatmos/common/Data/PACE/PACE_HARP2_L1C_SCI/PACE_HARP2.20250706T192050.L1C.V3.5km.nc"
ds = xr.open_dataset(path, group="geolocation_data")

data = ds["solar_zenith_angle"].mean(dim="number_of_views", skipna=True)
# data = ds["solar_zenith_angle"].isel(number_of_views=89)
# data = ds["solar_zenith_angle"][:,:,1]

lon = ds["longitude"]
lat = ds["latitude"]

# Plot
plt.figure(figsize=(8, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
img = ax.pcolormesh(lon[140:240, 240:340], lat[140:240, 240:340], data[140:240, 240:340], cmap="jet",)   # shading="auto"

ax.coastlines()
ax.add_feature(cfeature.COASTLINE, linewidth=1, edgecolor="black")
ax.add_feature(cfeature.BORDERS, linestyle=":", linewidth=0.8)
ax.set_title("Solar Zenith Angle", fontsize=12, color="k", fontweight="bold")

gl = ax.gridlines(draw_labels=True, x_inline=False, y_inline=False)
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.ylines = False

cbar = plt.colorbar(img, ax=ax, orientation="vertical", shrink=1, pad=0.05)
cbar.set_label("Solar Zenith Angle (°)")


mean_sza = data[140:240, 240:340].mean().item()
print("Average SZA =", mean_sza)
plt.show()
# Out:
# Average SZA = 46.06068801879883

# %%
path = "/umbc/rs/pi_zzbatmos/common/Data/PACE/PACE_HARP2_L1C_SCI/PACE_HARP2.20250706T192050.L1C.V3.5km.nc"
ds = xr.open_dataset(path, group="geolocation_data")

data = ds["solar_azimuth_angle"].mean(dim="number_of_views", skipna=True)
# data = ds["solar_zenith_angle"].isel(number_of_views=89)
# data = ds["solar_zenith_angle"][:,:,1]

lon = ds["longitude"]
lat = ds["latitude"]

# Plot
plt.figure(figsize=(8, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
img = ax.pcolormesh(lon[140:240, 240:340], lat[140:240, 240:340], data[140:240, 240:340], cmap="jet",)  # shading="auto"

ax.coastlines()
ax.add_feature(cfeature.COASTLINE, linewidth=1, edgecolor="black")
ax.add_feature(cfeature.BORDERS, linestyle=":", linewidth=0.8)
ax.set_title("Solar Azimuth Angle", fontsize=12, color="k", fontweight="bold")

gl = ax.gridlines(draw_labels=True, x_inline=False, y_inline=False)
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.ylines = False

cbar = plt.colorbar(img, ax=ax, orientation="vertical", shrink=1, pad=0.05)
cbar.set_label("Solar Azimuth Angle (°)")


mean_saa = data[140:240, 240:340].mean().item()
print("Average SAA =", mean_saa)
plt.show()
# Out:
# Average SAA = -23.454647064208984

# %%
path = "/umbc/rs/pi_zzbatmos/common/Data/PACE/PACE_HARP2_L1C_SCI/PACE_HARP2.20250706T192050.L1C.V3.5km.nc"
ds = xr.open_dataset(path, group="geolocation_data")

data = ds["sensor_azimuth_angle"].mean(dim="number_of_views", skipna=True)
# data = ds["solar_zenith_angle"].isel(number_of_views=89)
# data = ds["solar_zenith_angle"][:,:,1]

lon = ds["longitude"]
lat = ds["latitude"]

# Plot
plt.figure(figsize=(8, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
img = ax.pcolormesh(lon[140:240, 240:340], lat[140:240, 240:340], data[140:240, 240:340], cmap="jet",)  # shading="auto"

ax.coastlines()
ax.add_feature(cfeature.COASTLINE, linewidth=1, edgecolor="black")
ax.add_feature(cfeature.BORDERS, linestyle=":", linewidth=0.8)
ax.set_title("View Azimuth Angle", fontsize=12, color="k", fontweight="bold")

gl = ax.gridlines(draw_labels=True, x_inline=False, y_inline=False)
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.ylines = False

cbar = plt.colorbar(img, ax=ax, orientation="vertical", shrink=1, pad=0.05)
cbar.set_label("View Azimuth Angle (°)")


mean_vaa = data[140:240, 240:340].mean().item()
print("Average VAA =", mean_vaa)
plt.show()
# Out:
# Average VAA = -26.480531692504883

# %%
path = "/umbc/rs/pi_zzbatmos/common/Data/PACE/PACE_HARP2_L1C_SCI/PACE_HARP2.20250706T192050.L1C.V3.5km.nc"
ds = xr.open_dataset(path, group="geolocation_data")

data = ds["sensor_zenith_angle"].mean(dim="number_of_views", skipna=True)
# data = ds["solar_zenith_angle"].isel(number_of_views=89)
# data = ds["solar_zenith_angle"][:,:,1]

lon = ds["longitude"]
lat = ds["latitude"]

# Plot
plt.figure(figsize=(8, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
img = ax.pcolormesh(lon[140:240, 240:340], lat[140:240, 240:340], data[140:240, 240:340], cmap="jet",)  # shading="auto"

ax.coastlines()
ax.add_feature(cfeature.COASTLINE, linewidth=1, edgecolor="black")
ax.add_feature(cfeature.BORDERS, linestyle=":", linewidth=0.8)
ax.set_title("View Zenith Angle", fontsize=12, color="k", fontweight="bold")

gl = ax.gridlines(draw_labels=True, x_inline=False, y_inline=False)
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.ylines = False

cbar = plt.colorbar(img, ax=ax, orientation="vertical", shrink=1, pad=0.05)
cbar.set_label("View Zenith Angle (°)")


mean_vza = data[140:240, 240:340].mean().item()
print("Average VZA =", mean_vza)
plt.show()
# Out:
# Average VZA = 40.89570236206055

# %%
data.shape
# Out:
# (396, 519)
